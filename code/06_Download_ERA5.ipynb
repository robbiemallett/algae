# %%
import cdsapi

dataset = "reanalysis-era5-single-levels"
request = {
    "product_type": ["reanalysis"],
    "variable": ["surface_solar_radiation_downwards"],
    "year": ["2022"],
    "month": ["08"],
    "day": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
        "13", "14","15","16","17",
    ],
    "time": [
        "00:00", "01:00", "02:00",
        "03:00", "04:00", "05:00",
        "06:00", "07:00", "08:00",
        "09:00", "10:00", "11:00",
        "12:00", "13:00", "14:00",
        "15:00", "16:00", "17:00",
        "18:00", "19:00", "20:00",
        "21:00", "22:00", "23:00"
    ],
    "data_format": "netcdf",
    "download_format": "unarchived",
    "area": [90, -180, 66, 180]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download('../aux_data/reanalysis_Aug.nc')
# Out:
# 2026-03-20 14:22:37,828 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-03-20 14:22:37,830 INFO Request ID is c656afcd-5452-46bb-b288-d078fc538569
# 2026-03-20 14:22:37,949 INFO status has been updated to accepted
# 2026-03-20 14:22:51,950 INFO status has been updated to running
# 2026-03-20 14:23:28,516 INFO status has been updated to successful
# 1b1dd1111563ce9abf6e23853e627278.nc:   0%|          | 0.00/70.2M [00:00<?, ?B/s]
# '../aux_data/reanalysis_Aug.nc'

# %%
dataset = "reanalysis-era5-single-levels"
request = {
    "product_type": ["reanalysis"],
    "variable": ["surface_solar_radiation_downwards"],
    "year": ["2022"],
    "month": ["07"],
    "day": [
        "29","30","31",
    ],
    "time": [
        "00:00", "01:00", "02:00",
        "03:00", "04:00", "05:00",
        "06:00", "07:00", "08:00",
        "09:00", "10:00", "11:00",
        "12:00", "13:00", "14:00",
        "15:00", "16:00", "17:00",
        "18:00", "19:00", "20:00",
        "21:00", "22:00", "23:00"
    ],
    "data_format": "netcdf",
    "download_format": "unarchived",
    "area": [90, -180, 66, 180]
}
client = cdsapi.Client()
client.retrieve(dataset, request).download('../aux_data/reanalysis_Jul.nc')
# Out:
# 2025-09-23 09:05:33,155 INFO [2025-09-03T00:00:00] To improve our C3S service, we need to hear from you! Please complete this very short [survey](https://confluence.ecmwf.int/x/E7uBEQ/). Thank you.
# 2025-09-23 09:05:33,155 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-23 09:05:33,578 INFO Request ID is b93c4d0f-0dd3-4589-92c2-48c68b2beff8
# 2025-09-23 09:05:33,733 INFO status has been updated to accepted
# 2025-09-23 09:05:42,539 INFO status has been updated to running
# 2025-09-23 09:06:07,092 INFO status has been updated to successful
# 1895db92a1158440273490fcb07c4875.nc:   0%|          | 0.00/10.7M [00:00<?, ?B/s]
# '../aux_data/reanalysis_Jul.nc'
